,2502,2503,2505,2507,2514,2516,2520,2523,2524,2525,2526,2527,2528,2531,2532,2533,2534,2535,2536,2537,2538,2539,2540,2541,2542,2545,2546,2549,2550,2551,2552,2553,2554,2555,2556,2557,2559,2561,2571,2581,2591,2601,2602,2604,2605,2606,2607,2608,2609,2610,2611,2612,2614,2618,2619,2620,2625,2627,2628,2630,2631,2632,2633,2634,2635,2636,2637,2638,2639,2640,2644,2645,2646,2648,2651,2654,2656,2657,2658,2659,2660,2661,2662,2663,2664,2666,2670,2671,2672,2674,2677,2679,2680,2682,2683,2684,2685,2686,2687,2688,2689,2690,2692,2696,2697,2698,2700,2703,2705,2706,2708,2709,2710,2711,2712,2713,2714,2715,2716,2718,2722,2723,2724,2726,2729,2731,2732,2734,2735,2736,2737,2738,2739,2740,2741,2742,2744,2748,2749,2755,2812,2815,2818,2821,2824,2827,2830,2833,2836,2840,2842,2843,2845,2846,2848,2849,2851,2852,2854,2855,2857,2858,2860,2861,2864,2870,2871,2873,2874,2876,2877,2879,2880,2882,2883,2885,2886,2888,2889,2892,2896,2898,2901,2904,2907,2910,2913,2916,2920,2940,2944,2946,3009,3096,3098,3099,3165,3169,3181,3188,3194,3195,3196,3197,3198,3199,3212,3225,3231,3233,3236,3245,3248,3253,3258,3263,3266,3271,3276,3281,3286,32 ...
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### Remove all non-response in Wave B

# %%
data_clean = data[data.BA12.notnull()]

# %% [markdown]
# #### Remove all non-responses in Wave C but keep the ones that fail in Wave B

# %%
fail = data_clean[data.survive_2 == 0]
non_drop = data_clean[data.CA12.notnull()]
frames = [fail, non_drop]

data = pd.concat(frames)

# %% [markdown]
# #### Re-weight the new subset of data so that the weights are centered at 1

# %%
data["Weight"] = data.WT_WAVEB/ data.WT_WAVEB.mean()

# %% [markdown]
# #### Remove all unncessary columns

# %%
data_clean = data[['education_smaller', 'work_experience','entrep_exp','industry_exp', 'manager_exp', 'survive_3', 'profit', 'rev', 'white', 'parents', 'team_size', 'major_reason', 'manager_exp', 'alone_or_not', 'industry_code', 'net_worth', '35hours', 'net_worth_dummy', 'Gender', 'WT_WAVEA', 'WT_WAVEB', 'WT_WAVEC', 'Weight', 'REGIONA']]

# %%
data_clean.head()
# Out:
#        education_smaller  work_experience  entrep_exp  industry_exp  \
# 8   High School or Below               15           0             0
# 11  High School or Below               12           0             1
# 15          Some college               40           0             1
# 16  High School or Below                1           0             0
# 20          Some college               18           1             1
#
#     manager_exp  survive_3  profit  rev  white  parents    ...      \
# 8             1          0       0    0      1        0    ...
# 11            1          0       0    0      1        1    ...
# 15            1          0       0    1      1        0    ...
# 16            0          0       0    0      0        0    ...
# 20            1          0       0    0      1        1    ...
#
#     industry_code  net_worth  35hours  net_worth_dummy  Gender  WT_WAVEA  \
# 8               2          0        0                0    Male  1.690526
# 11              3      16000        0                1    Male  1.034412
# 15              4     221800        0                1  Female  0.583769
# 16              5          0        0                0    Male  2.470518
# 20              3      -6600        0                1    Male  0.514979
#
#     WT_WAVEB  WT_WAVEC    Weight    REGIONA
# 8   1.105440  1.524656  1.132551  Northeast
# 11  1.148580  1.016526  1.176749    Midwest
# 15  0.579134  0.540922  0.593338  Northeast
# 16  2.167183  2.817570  2.220334      South
# 20  0.802419  0.551512  0.822098       West
#
# [5 rows x 24 columns]

# %%
data_final.to_csv('data_npremoved.csv', encoding = 'utf-8')
